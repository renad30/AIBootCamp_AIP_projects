# %% [markdown]
# <a href="https://colab.research.google.com/github/renad30/AIBootCamp_AIP_projects/blob/main/Day_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Python**
# ![python-1.jpg](data:image/jpeg;base64,...)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## **python variable**

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
# Print your name from user inputs
x=input()
print(x)
# Out:
# renad
# renad

# %% [markdown]
# ## **Variable type**

# %%
number = 5
print(type(number))
# Out:
# <class 'int'>

# %%
# Print your name from user inputs and data type
x=input()
print(x)
print(type(x))
# Out:
# renad
# renad
# <class 'str'>

# %% [markdown]
# ## **String**

# %% [markdown]
# ###**Methods**

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
a = "    Hello, World!     "
print(a.strip()) # returns "Hello, World!"
# Out:
# Hello, World!

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World!']

# %%
age = 36
txt = "My name is John, and I am {}"
print(txt.format(age))
# Out:
# My name is John, and I am 36

# %%
#Use the len() function to print the length of the string
X = "hello"
print(len(x))
# Out:
# 5

# %% [markdown]
# ##**Booleans**

# %%
x = "Hello"
y = 15

print(bool(x))
print(bool(y))

#print 0 if 0 or false or empty list or non
# Out:
# True
# True

# %% [markdown]
# ##**Operators**

# %%
print((6 + 3) - (6 + 3))
# Out:
# 0

# %%
#Ask the user to enter his age and calculate his age after 5 years
age= 21
sum= age+5
print('Your age after 5 years is :', sum )
# Out:
# Your age after 5 years is : 26

# %% [markdown]
# ##**List**

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
print(thislist[1])
# Out:
# ['apple', 'banana', 'cherry']
# banana

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "grape"
print(thislist)
# Out:
# ['apple', 'grape', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
# create a list with strings, integers and boolean values
thislist=['renad',20,True]
# print the last item , use index
print(thislist[2])
# Out:
# True

# %% [markdown]
# ##**tuples**

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

# To join two or more tuples you can use the + operator:


print(tuple1+tuple2)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %% [markdown]
# ##**sets**

# %%
thisset = {"apple", "banana", "cherry"}

print(len(thisset))
# Out:
# 3

# %% [markdown]
# ##**Dictionaries**

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %%
#nasted

myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

# %%
print(myfamily["child2"]["name"])
# Out:
# Tobias

# %% [markdown]
# ##**If ... Else**

# %%
name=input("enter your name: ")

if (name=="AIP"):
    print("Hi,AIP")
    print("welcome to the system")
else:
    print("Hello, Stranger")
# Out:
# enter your name: renad
# Hello, Stranger

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
#Short Hand If
a = 200
b = 33
print("b is greater than a") if b > a else print("b is not greater than a")
# Out:
# b is not greater than a

# %%
#nasted
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
# create a program to validate the username and password ,
username= input('enter username: ')
password= input('enter password: ')

# if username and password are correct the user can use the system .
if username =="AIP"and password =="kfu":
    print("welcome to the system!")

# otherwise ask him to enter them again
else:
    print("Incorrect username or password")
# Out:
# enter username: renad
# enter password: eidj9o
# Incorrect username or password

# %% [markdown]
# ##**loop**

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in "Coding":
  print(x)
# Out:
# C
# o
# d
# i
# n
# g

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2, 6):
  print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
#Print all numbers from 0 to 5, and print a message when the loop has ended
for x in range(0,6):
  print(x)
print ('one piece')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# one piece

# %% [markdown]
# ##**Functions**

# %%
def my_function():
  print("Hello from a function")

my_function()
# Out:
# Hello from a function

# %%
# Parameters , Arguments
def my_function(fname, lname):
  print(fname,lname)

my_function("jhon", "smith")
# Out:
# jhon smith

# %%
#return value
def my_function(x):
  return 5 * x

print(my_function(3))
print(my_function(5))
print(my_function(9))
# Out:
# 15
# 25
# 45

# %%
# the check_number function takes an integer number as an argument
def check_number(x):
# and uses an if-else statement to determine if the number is positive, negative, or zero.
 if x >0 :
   print('positive')
# It returns "Positive" if the number is greater than 0,
 elif x<0:
   print ('negative')

# "Negative" if it's less than 0,
 else :
  print ('its 0')
# and "Zero" if it's exactly 0.

num = 42
print(check_number(num))
# Out:
# positive
# None
